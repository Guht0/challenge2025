# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold, cross_val_score
from catboost import CatBoostClassifier

# 1. Carrega os dados
df = pd.read_csv('../docs/dados.csv')

# 2. Separa X e y
X = df.drop(['Unnamed: 0', 'notas'], axis=1)
y = df['notas'].astype(int)

# 3. Lista de colunas categóricas
cat_cols = X.select_dtypes(include=['object']).columns.tolist()

# 4. Define o modelo
model = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.05,
    loss_function='MultiClass',    # classificador 5‑classes
    eval_metric='Accuracy',        # ou 'WKappa'
    cat_features=cat_cols,
    random_seed=42,
    verbose=100
)

# 5. Validação cruzada estratificada
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(
    model, X, y,
    cv=cv,
    scoring='neg_mean_absolute_error'
)

print("MAE médio:", -scores.mean())
# Out:
# 0:	learn: 0.4125000	total: 58.8ms	remaining: 58.8s
# 100:	learn: 0.4437500	total: 1.41s	remaining: 12.5s
# 200:	learn: 0.6975000	total: 2.69s	remaining: 10.7s
# 300:	learn: 0.9325000	total: 3.95s	remaining: 9.16s
# 400:	learn: 0.9875000	total: 5.23s	remaining: 7.81s
# 500:	learn: 0.9962500	total: 6.51s	remaining: 6.48s
# 600:	learn: 0.9987500	total: 7.75s	remaining: 5.15s
# 700:	learn: 1.0000000	total: 8.96s	remaining: 3.82s
# 800:	learn: 1.0000000	total: 10.2s	remaining: 2.54s
# 900:	learn: 1.0000000	total: 11.5s	remaining: 1.26s
# 999:	learn: 1.0000000	total: 12.7s	remaining: 0us
# 0:	learn: 0.4125000	total: 776us	remaining: 776ms
# 100:	learn: 0.4662500	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.7250000	total: 2.47s	remaining: 9.81s
# 300:	learn: 0.9325000	total: 3.72s	remaining: 8.63s
# 400:	learn: 0.9912500	total: 4.97s	remaining: 7.43s
# 500:	learn: 1.0000000	total: 6.22s	remaining: 6.2s
# 600:	learn: 1.0000000	total: 7.47s	remaining: 4.96s
# 700:	learn: 1.0000000	total: 8.75s	remaining: 3.73s
# 800:	learn: 1.0000000	total: 10.1s	remaining: 2.5s
# 900:	learn: 1.0000000	total: 11.4s	remaining: 1.25s
# 999:	learn: 1.0000000	total: 12.6s	remaining: 0us
# 0:	learn: 0.4200000	total: 10.4ms	remaining: 10.4s
# 100:	learn: 0.4462500	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.6862500	total: 2.47s	remaining: 9.81s
# 300:	learn: 0.9150000	total: 3.75s	remaining: 8.7s
# 400:	learn: 0.9825000	total: 5.08s	remaining: 7.58s
# 500:	learn: 0.9975000	total: 6.34s	remaining: 6.32s
# 600:	learn: 1.0000000	total: 7.62s	remaining: 5.06s
# 700:	learn: 1.0000000	total: 8.92s	remaining: 3.81s
# 800:	learn: 1.0000000	total: 10.2s	remaining: 2.54s
# 900:	learn: 1.0000000	total: 11.5s	remaining: 1.26s
# 999:	learn: 1.0000000	total: 12.7s	remaining: 0us
# 0:	learn: 0.4275000	total: 12.1ms	remaining: 12.1s
# 100:	learn: 0.4462500	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.7000000	total: 2.41s	remaining: 9.6s
# 300:	learn: 0.9375000	total: 3.69s	remaining: 8.57s
# 400:	learn: 0.9937500	total: 4.93s	remaining: 7.37s
# 500:	learn: 0.9987500	total: 6.23s	remaining: 6.21s
# 600:	learn: 1.0000000	total: 7.59s	remaining: 5.04s
# 700:	learn: 1.0000000	total: 9.02s	remaining: 3.85s
# 800:	learn: 1.0000000	total: 10.4s	remaining: 2.58s
# 900:	learn: 1.0000000	total: 11.7s	remaining: 1.28s
# 999:	learn: 1.0000000	total: 12.9s	remaining: 0us
# 0:	learn: 0.4175000	total: 12.1ms	remaining: 12.1s
# 100:	learn: 0.4400000	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.7062500	total: 2.47s	remaining: 9.83s
# 300:	learn: 0.9425000	total: 3.76s	remaining: 8.73s
# 400:	learn: 0.9912500	total: 5.04s	remaining: 7.52s
# 500:	learn: 1.0000000	total: 6.3s	remaining: 6.28s
# 600:	learn: 1.0000000	total: 7.57s	remaining: 5.03s
# 700:	learn: 1.0000000	total: 8.82s	remaining: 3.76s
# 800:	learn: 1.0000000	total: 10.1s	remaining: 2.51s
# 900:	learn: 1.0000000	total: 11.4s	remaining: 1.25s
# 999:	learn: 1.0000000	total: 12.6s	remaining: 0us
# MAE médio: 0.845

# %%
from sklearn.model_selection import KFold, cross_val_score
from catboost import CatBoostRegressor
import pandas as pd

df = pd.read_csv('../docs/dados.csv')
X = df.drop(['Unnamed: 0', 'notas'], axis=1)
y = df['notas']  # mantém float ou int, ambos funcionam

cat_cols = X.select_dtypes(include=['object']).columns.tolist()

model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.05,
    loss_function='MAE',       # otimiza diretamente o MAE
    cat_features=cat_cols,
    random_seed=42,
    verbose=100
)

cv = KFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(
    model, X, y,
    cv=cv,
    scoring='neg_mean_absolute_error'
)

print("MAE médio (regressor):", -scores.mean())
# Out:
# 0:	learn: 0.8514367	total: 13.9ms	remaining: 13.9s
# 100:	learn: 0.7447874	total: 347ms	remaining: 3.09s
# 200:	learn: 0.6223942	total: 692ms	remaining: 2.75s
# 300:	learn: 0.5272827	total: 1.03s	remaining: 2.38s
# 400:	learn: 0.4705013	total: 1.35s	remaining: 2.01s
# 500:	learn: 0.4262035	total: 1.68s	remaining: 1.67s
# 600:	learn: 0.3892909	total: 2.02s	remaining: 1.34s
# 700:	learn: 0.3601218	total: 2.34s	remaining: 1000ms
# 800:	learn: 0.3366896	total: 2.67s	remaining: 664ms
# 900:	learn: 0.3176017	total: 3.01s	remaining: 331ms
# 999:	learn: 0.2978284	total: 3.34s	remaining: 0us
# 0:	learn: 0.8840617	total: 3.21ms	remaining: 3.21s
# 100:	learn: 0.7754473	total: 276ms	remaining: 2.45s
# 200:	learn: 0.6834782	total: 589ms	remaining: 2.34s
# 300:	learn: 0.6030060	total: 915ms	remaining: 2.12s
# 400:	learn: 0.5307996	total: 1.24s	remaining: 1.86s
# 500:	learn: 0.4864610	total: 1.58s	remaining: 1.57s
# 600:	learn: 0.4493609	total: 1.9s	remaining: 1.26s
# 700:	learn: 0.4233076	total: 2.23s	remaining: 952ms
# 800:	learn: 0.3945016	total: 2.56s	remaining: 636ms
# 900:	learn: 0.3723333	total: 2.9s	remaining: 319ms
# 999:	learn: 0.3516819	total: 3.24s	remaining: 0us
# 0:	learn: 0.8770617	total: 3.32ms	remaining: 3.31s
# 100:	learn: 0.7585366	total: 329ms	remaining: 2.92s
# 200:	learn: 0.6290788	total: 647ms	remaining: 2.57s
# 300:	learn: 0.5325508	total: 971ms	remaining: 2.25s
# 400:	learn: 0.4727156	total: 1.29s	remaining: 1.93s
# 500:	learn: 0.4238725	total: 1.62s	remaining: 1.62s
# 600:	learn: 0.3885478	total: 1.94s	remaining: 1.29s
# 700:	learn: 0.3584345	total: 2.27s	remaining: 967ms
# 800:	learn: 0.3341539	total: 2.6s	remaining: 645ms
# 900:	learn: 0.3155000	total: 2.92s	remaining: 321ms
# 999:	learn: 0.2987280	total: 3.25s	remaining: 0us
# 0:	learn: 0.8921867	total: 3.48ms	remaining: 3.48s
# 100:	learn: 0.7764707	total: 287ms	remaining: 2.55s
# 200:	learn: 0.6614503	total: 612ms	remaining: 2.43s
# 300:	learn: 0.5584353	total: 935ms	remaining: 2.17s
# 400:	learn: 0.4975970	total: 1.31s	remaining: 1.95s
# 500:	learn: 0.4462310	total: 1.64s	remaining: 1.63s
# 600:	learn: 0.4030653	total: 1.97s	remaining: 1.3s
# 700:	learn: 0.3689770	total: 2.29s	remaining: 977ms
# 800:	learn: 0.3407621	total: 2.62s	remaining: 651ms
# 900:	learn: 0.3171911	total: 2.94s	remaining: 324ms
# 999:	learn: 0.2966644	total: 3.26s	remaining: 0us
# 0:	learn: 0.8637180	total: 4.55ms	remaining: 4.55s
# 100:	learn: 0.7663029	total: 271ms	remaining: 2.41s
# 200:	learn: 0.6438200	total: 588ms	remaining: 2.34s
# 300:	learn: 0.5547416	total: 910ms	remaining: 2.11s
# 400:	learn: 0.4881878	total: 1.25s	remaining: 1.86s
# 500:	learn: 0.4401075	total: 1.57s	remaining: 1.56s
# 600:	learn: 0.4009183	total: 1.9s	remaining: 1.26s
# 700:	learn: 0.3686345	total: 2.21s	remaining: 945ms
# 800:	learn: 0.3451061	total: 2.54s	remaining: 632ms
# 900:	learn: 0.3158251	total: 2.85s	remaining: 314ms
# 999:	learn: 0.2983061	total: 3.17s	remaining: 0us
# MAE médio (regressor): 0.9465384457755613

# %% [markdown]
# ## Modelo Classifier apresentou um MAE menor o tornando mais atrativo

# %%
# Testando hiperparametros

from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from catboost import CatBoostClassifier

# 1. Carrega os dados
df = pd.read_csv('../docs/dados.csv')

# 2. Separa X e y
X = df.drop(['Unnamed: 0', 'notas'], axis=1)
y = df['notas'].astype(int)

# 3. Lista de colunas categóricas
cat_cols = X.select_dtypes(include=['object']).columns.tolist()

# 1) Defina o modelo base
model = CatBoostClassifier(
    loss_function='MultiClass',
    eval_metric='Accuracy',
    cat_features=cat_cols,
    random_seed=42,
    verbose=0
)

# 2) Escolha o espaço de busca
param_distribs = {
    'iterations':       [200, 500, 1000],
    'learning_rate':    [0.01, 0.03, 0.05, 0.1],
    'depth':            [4, 6, 8, 10],
    'l2_leaf_reg':      [1, 3, 5, 7, 9],
    'border_count':     [32, 64, 128]
}

# 3) Configure o RandomizedSearchCV
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distribs,
    n_iter=30,                   # quantos conjuntos testar
    scoring='neg_mean_absolute_error',
    cv=cv,
    random_state=42,
    verbose=2,
    n_jobs=-1
)

# 4) Rode a busca
search.fit(X, y)

# 5) Veja os melhores parâmetros e o score
print("Melhores params:", search.best_params_)
print("Melhor MAE:", -search.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05; total time=  29.2s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05; total time=  29.8s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05; total time=  30.2s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05; total time=  28.6s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05; total time=  29.0s
# [CV] END border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.05; total time=  28.7s
# [CV] END border_count=64, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01; total time= 1.0min
# [CV] END border_count=64, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01; total time= 1.0min
# [CV] END border_count=64, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01; total time= 1.0min
# [CV] END border_count=64, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01; total time= 1.0min
# [CV] END border_count=64, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.01; total time= 1.0min
# [CV] END border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.05; total time=  43.9s
# [CV] END border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.05; total time=  44.6s
# [CV] END border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.05; total time=  46.6s
# [CV] END border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.05; total time=  48.1s
# [CV] END border_count=32, depth=10, iterations=200, l2_leaf_reg=9, learning_rate=0.05; total time= 1.3min
# [CV] END border_count=32, depth=10, iterations=200, l2_leaf_reg=9, learning_rate=0.05; total time= 1.3min
# [CV] END border_count=32, depth=10, iterations=200, l2_leaf_reg=9, learning_rate=0.05; total time= 1.3min
# [CV] END border_count=32, depth=10, iterations=200, l2_leaf_reg=9, learning_rate=0.05; total time= 1.3min
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.03; total time=  24.9s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.03; total time=  24.7s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.03; total time=  25.1s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.03; total time=  24.1s
# [CV] END border_count=32, depth=10, iterations=200, l2_leaf_reg=9, learning_rate=0.05; total time= 1.5min
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=3, learning_rate=0.03; total time=  23.2s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1; total time=  24.1s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1; total time=  23.2s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1; total time=  22.7s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1; total time=  22.9s
# [CV] END border_count=32, depth=6, iterations=200, l2_leaf_reg=1, learning_rate=0.1; total time=  23.2s
# /Users/gustavo_hoodini/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END border_count=32, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 1.6min
# [CV] END border_count=32, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 1.6min
# [CV] END border_count=64, depth=10, iterations=500, l2_leaf_reg=7, learning_rate=0.03; total time= 3.9min
# [CV] END border_count=32, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 1.6min
# [CV] END border_count=64, depth=10, iterations=500, l2_leaf_reg=7, learning_rate=0.03; total time= 3.9min
# [CV] END border_count=64, depth=10, iterations=500, l2_leaf_reg=7, learning_rate=0.03; total time= 3.9min
# [CV] END border_count=64, depth=10, iterations=500, l2_leaf_reg=7, learning_rate=0.03; total time= 3.7min
# [CV] END border_count=64, depth=10, iterations=500, l2_leaf_reg=7, learning_rate=0.03; total time= 3.7min
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.01; total time=  32.5s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.01; total time=  32.4s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.01; total time=  31.3s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.01; total time=  31.2s
# [CV] END border_count=64, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.01; total time=  30.7s
# [CV] END border_count=32, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 1.1min
# [CV] END border_count=32, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.03; total time= 1.1min
# [CV] END border_count=64, depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time= 1.2min
# [CV] END border_count=64, depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time= 1.4min
# [CV] END border_count=64, depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time= 1.4min
# [CV] END border_count=64, depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time= 1.4min
# [CV] END border_count=64, depth=8, iterations=500, l2_leaf_reg=5, learning_rate=0.05; total time= 1.4min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 48
#      36 search = RandomizedSearchCV(
#      37     estimator=model,
#      38     param_distributions=param_distribs,
#    (...)     44     n_jobs=-1
#      45 )
#      47 # 4) Rode a busca
# ---> 48 search.fit(X, y)
#      50 # 5) Veja os melhores parâmetros e o score
#      51 print("Melhores params:", search.best_params_)
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1951, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1949 def _run_search(self, evaluate_candidates):
#    1950     """Search n_iter candidates from param_distributions"""
# -> 1951     evaluate_candidates(
#    1952         ParameterSampler(
#    1953             self.param_distributions, self.n_iter, random_state=self.random_state
#    1954         )
#    1955     )
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/Development/DataScience/Challenge_jeans/.venv/lib/python3.12/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
