# %%
import pandas as pd

# %%
df = pd.read_csv('docs/calca_jeans.csv', sep=';')

# %%
df.head()
# Out:
#    Cod_Venda  Cod_Data DataNotaFiscal  Dia  Mes   Ano Cod_Marca      Marca  \
# 0          1     43687     10/08/2019   10    8  2019       M05    Milteka
# 1          2     42474     14/04/2016   14    4  2016       M05    Milteka
# 2          3     44064     21/08/2020   21    8  2020       M05    Milteka
# 3          4     43271     20/06/2018   20    6  2018       M04    Salvion
# 4          5     44104     30/09/2020   30    9  2020       M03  Patrilolo
#
#    UF       Nome_UF  ... Cod_Filial  Nome_Filial Estado_Filial  \
# 0  PR        Paraná  ...          4        Bauru            SP
# 1  PI         Piauí  ...          4        Bauru            SP
# 2  BA         Bahia  ...          1  Allenópolis            SP
# 3  MG  Minas Gerais  ...          1  Allenópolis            SP
# 4  RO      Rondônia  ...          3    Rio Claro            MG
#
#                Demog_Clientes Meios_de_Pag                   Cat_de_Produtos  \
# ...

# %%
df['notas'] = df['Indi_Satisfacao'].str.extract(r'(\d+(?:\.\d+)?)').astype(float)

# %%
print(df['notas'])
# Out:
# 0      3.0
# 1      4.5
# 2      2.0
# 3      5.0
# 4      3.0
#       ...
# 995    2.0
# 996    2.0
# 997    3.0
# 998    3.0
# 999    5.0
# Name: notas, Length: 1000, dtype: float64
